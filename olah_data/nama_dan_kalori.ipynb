# %%
import pandas as pd
pd.set_option('display.max_rows', None)

# %%
df = pd.read_csv('calories.csv')
df
# Out:
#                        FoodCategory  \
# 0                       CannedFruit
# 1                       CannedFruit
# 2                       CannedFruit
# 3                       CannedFruit
# 4                       CannedFruit
# 5                       CannedFruit
# 6                       CannedFruit
# 7                       CannedFruit
# 8                       CannedFruit
# 9                       CannedFruit
# 10                      CannedFruit
# 11                      CannedFruit
# 12                      CannedFruit
# 13                      CannedFruit
# 14                      CannedFruit
# 15                      CannedFruit
# 16                      CannedFruit
# 17                      CannedFruit
# 18                      CannedFruit
# 19                      CannedFruit
# 20                      CannedFruit
# 21                      CannedFruit
# 22                      CannedFruit
# 23                      CannedFruit
# 24                      CannedFruit
# ...

# %%
df1 = df[['FoodItem', 'per100grams', 'Cals_per100grams']]
df1
# Out:
#                                        FoodItem per100grams Cals_per100grams
# 0                                    Applesauce        100g           62 cal
# 1                               Canned Apricots        100g           48 cal
# 2                           Canned Blackberries        100g           92 cal
# 3                            Canned Blueberries        100g           88 cal
# 4                               Canned Cherries        100g           54 cal
# 5                            Canned Cranberries        100g          178 cal
# 6                      Canned Crushed Pineapple        100g           53 cal
# 7                                   Canned Figs        100g          107 cal
# 8                         Canned Fruit Cocktail        100g           81 cal
# 9                            Canned Fruit Salad        100g           50 cal
# 10                          Canned Gooseberries        100g           73 cal
# ...

# %%
if df1.info() == df.info():
    print("YEAH BANGET")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2225 entries, 0 to 2224
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   FoodItem     2225 non-null   object
#  1   per100grams  2225 non-null   object
# dtypes: object(2)
# memory usage: 34.9+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2225 entries, 0 to 2224
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   FoodCategory      2225 non-null   object
#  1   FoodItem          2225 non-null   object
#  2   per100grams       2225 non-null   object
#  3   Cals_per100grams  2225 non-null   object
#  4   KJ_per100grams    2225 non-null   object
# dtypes: object(5)
# memory usage: 87.0+ KB
# YEAH BANGET

# %%
df1.to_csv('nama_dan_kalori.csv', index=False)
